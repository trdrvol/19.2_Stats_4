# %%
"""
Using the following data, perform a oneway analysis of variance using α=.05. Write up
the results in APA format.

[Group1: 51, 45, 33, 45, 67]
[Group2: 23, 43, 23, 43, 45]
[Group3: 56, 76, 74, 87, 56]

Note: Solution submitted via github must
"""

# %%
"""
One way ANOVA analysis problem set:

First we take sample average/mean (xbar) of each Group:
Group 1 : 48.2
Group 2 : 35.4
Group 3: 69.8

Group 1:

Data    Mean    Difference    Squared deviations
51      48.2      2.8                7.84
45      48.2     -3.2               10.24
33      48.2     -15.2              231.04
45      48.2     -3.2               10.24
67      48.2     18.8               353.44

For group 2 and 3 we do the same as above.

Sum of the squared deviations from the mean,SS for the groups are mentioned as follows:

Group 1: 612.8
Group 2: 515.2
Group 3: 732.8

Var1: 612.8/5-1 = 153.2  ( Variance, sigma square = sigma (xi-xbar)square/n-1)
Var2: 128.8
Var3:183.2

MSE(Mean squared error) = 153.2 + 128.8 + 183.2/3 = 155.07
(Average WITHIN group variance)


df error = 15-3 = 12
SS error= 155.07 * 12 = 1860.8

Next we calculate Grand mean:

Grand mean = 48.2 + 35.4 + 69.8/3 = 51.13

Group mean     Grand mean     Squared deviations
48.2             51.13             8.58
35.4             51.13           247.43
69.8             51.13           348.57

Sum of squares mean = 604.58
Var(means)= 604.58/3-1 = 302.29
MS(between groups)=302.29 * 5 = 1511.45
df(between)=3-1 = 2
SS(groups)= 1511.45 * 2= 3022.9

F=MS(between groups)/MS(within groups)
=1511.45/155.07
=9.75

F(critical)(2,12)= 3.89

since F is greater than Fcritical so we rejevt Null Hypothesis.

ANOVA table:

Source    SS        df        MS         F
Group    3022.9     2       1511.45     9.75
Error    1860.8     12      155.07
Total    4883.7

Efeect size = 3022.9/4883.7 = .62

F(2,12)=9.75,p<0.05, Neta square = 0.62
"""
